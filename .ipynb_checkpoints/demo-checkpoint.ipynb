# %% [markdown]
# # Identifying Bees Using Crowd Sourced Data using Amazon SageMaker
#
# ### Table of contents
# 1. [Introduction to dataset](#introduction)
# 2. [Labeling with Amazon SageMaker Ground Truth](#groundtruth)
# 3. [Reviewing labeling results](#review)
# 4. [Training an Object Detection model](#training)
# 5. [Review of Training Results](#review_training)
# 6. [Model Tuning](#model_tuning)
# 7. [Cleanup](#cleanup)

# %% [markdown]
# <a name="introduction"></a>
# ## Introduction to dataset
# We will use a dataset from the [inaturalist.org](inaturalist.org) This dataset contains 500 images of bees that have been uploaded by inaturalist users for the purposes of recording the observation and identification. We only used images that their users have licensed under [CC0](https://creativecommons.org/share-your-work/public-domain/cc0/) license. For your convenience, we have placed the dataset in S3 in a single zip archive here: http://aws-tc-largeobjects.s3-us-west-2.amazonaws.com/DIG-TF-200-MLBEES-10-EN/dataset.zip
#
# First, download and unzip the archive.

# %%
# !wget http://aws-tc-largeobjects.s3-us-west-2.amazonaws.com/DIG-TF-200-MLBEES-10-EN/dataset.zip 
# !unzip -qo dataset.zip
# Out:
# --2020-05-04 18:25:57--  http://aws-tc-largeobjects.s3-us-west-2.amazonaws.com/DIG-TF-200-MLBEES-10-EN/dataset.zip
# Resolving aws-tc-largeobjects.s3-us-west-2.amazonaws.com (aws-tc-largeobjects.s3-us-west-2.amazonaws.com)... 52.218.218.65
# Connecting to aws-tc-largeobjects.s3-us-west-2.amazonaws.com (aws-tc-largeobjects.s3-us-west-2.amazonaws.com)|52.218.218.65|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 70375947 (67M) [application/x-zip-compressed]
# Saving to: ‘dataset.zip’
#
# dataset.zip         100%[===================>]  67.12M  6.62MB/s    in 11s
#
# 2020-05-04 18:26:09 (5.97 MB/s) - ‘dataset.zip’ saved [70375947/70375947]

# %% [markdown]
# The archive contains the following structure: 500 `.jpg` image files, a manifest file (to be explained later) and 10 test images in the `test` subfolder.

# %%
# !unzip -l dataset.zip | tail -20
# Out:
#    251027  05-15-2019 19:21   9530124.jpg
#    110561  05-15-2019 19:21   9542264.jpg
#    312354  05-15-2019 19:21   9543188.jpg
#     76903  05-15-2019 19:21   9637165.jpg
#     48663  05-15-2019 19:21   9765741.jpg
#     66393  05-15-2019 19:21   9787032.jpg
#    273392  05-22-2019 21:58   output.manifest
#         0  06-01-2019 05:51   test/
#     83438  06-01-2019 05:51   test/22427594.jpg
#    152133  06-01-2019 05:51   test/22469656.jpg
#    205930  06-01-2019 05:51   test/22544384.jpg
#    137755  06-01-2019 05:51   test/22673445.jpg
#    124565  06-01-2019 05:51   test/22741822.jpg
#     39502  06-01-2019 05:51   test/22774999.jpg
#     39086  06-01-2019 05:51   test/22775000.jpg
#    149389  06-01-2019 05:51   test/22901964.jpg
#    103322  06-01-2019 05:51   test/22971237.jpg
#    109178  06-01-2019 05:51   test/23086755.jpg
# ---------                     -------
#  70635014                     512 files

# %% [markdown]
# Now let's upload this dataset to your own S3 bucket in preparation for labeling and training using Amazon SageMaker. For this demo, we will be using `us-west-2` region, so your bucket needs to be in this region.

# %%
# S3 bucket must be created in us-west-2 (Oregon) region
BUCKET = 'mlbees'
PREFIX = 'input' # this is the root path to your working space, feel to use a different path

# %%
# !aws s3 sync --exclude="*" --include="[0-9]*.jpg" . s3://$BUCKET/$PREFIX/
# Out:
# warning: Skipping file /home/ec2-user/SageMaker/lost+found. File/Directory is not readable.
# upload: ./10250726.jpg to s3://mlbees/input/10250726.jpg
# upload: ./10006450.jpg to s3://mlbees/input/10006450.jpg
# upload: ./1063563.jpg to s3://mlbees/input/1063563.jpg
# upload: ./10311147.jpg to s3://mlbees/input/10311147.jpg
# upload: ./1025450.jpg to s3://mlbees/input/1025450.jpg
# upload: ./10437385.jpg to s3://mlbees/input/10437385.jpg
# upload: ./10299519.jpg to s3://mlbees/input/10299519.jpg
# upload: ./10022723.jpg to s3://mlbees/input/10022723.jpg
# upload: ./10631806.jpg to s3://mlbees/input/10631806.jpg
# upload: ./10059108.jpg to s3://mlbees/input/10059108.jpg
# upload: ./1060304.jpg to s3://mlbees/input/1060304.jpg
# upload: ./10658023.jpg to s3://mlbees/input/10658023.jpg
# upload: ./10694926.jpg to s3://mlbees/input/10694926.jpg
# upload: ./10983841.jpg to s3://mlbees/input/10983841.jpg
# upload: ./10551061.jpg to s3://mlbees/input/10551061.jpg
# upload: ./10665301.jpg to s3://mlbees/input/10665301.jpg
# upload: ./10923199.jpg to s3://mlbees/input/10923199.jpg
# upload: ./1091455.jpg to s3://mlbees/input/1091455.jpg
# upload: ./11186056.jpg to s3://mlbees/input/11186056.jpg
# upload: ./10937818.jpg to s3://mlbees/input/10937818.jpg
# upload: ./11257.jpg to s3://mlbees/input/11257.jpg
# upload: ./11558127.jpg to s3://mlbees/input/11558127.jpg
# upload: ./1135667.jpg to s3://mlbees/input/1135667.jpg
# upload: ./11424751.jpg to s3://mlbees/input/11424751.jpg
# upload: ./10632489.jpg to s3://mlbees/input/10632489.jpg
# upload: ./11519509.jpg to s3://mlbees/input/11519509.jpg
# upload: ./11421145.jpg to s3://mlbees/input/11421145.jpg
# upload: ./11340084.jpg to s3://mlbees/input/11340084.jpg
# upload: ./11543756.jpg to s3://mlbees/input/11543756.jpg
# upload: ./11523017.jpg to s3://mlbees/input/11523017.jpg
# upload: ./11617097.jpg to s3://mlbees/input/11617097.jpg
# upload: ./11519394.jpg to s3://mlbees/input/11519394.jpg
# upload: ./11626927.jpg to s3://mlbees/input/11626927.jpg
# upload: ./11668554.jpg to s3://mlbees/input/11668554.jpg
# upload: ./1167794.jpg to s3://mlbees/input/1167794.jpg
# upload: ./1188934.jpg to s3://mlbees/input/1188934.jpg
# upload: ./12010614.jpg to s3://mlbees/input/12010614.jpg
# upload: ./12116636.jpg to s3://mlbees/input/12116636.jpg
# upload: ./11658794.jpg to s3://mlbees/input/11658794.jpg
# upload: ./12122915.jpg to s3://mlbees/input/12122915.jpg
# upload: ./122171.jpg to s3://mlbees/input/122171.jpg
# upload: ./12372307.jpg to s3://mlbees/input/12372307.jpg
# upload: ./12368560.jpg to s3://mlbees/input/12368560.jpg
# upload: ./12441571.jpg to s3://mlbees/input/12441571.jpg
# upload: ./1226798.jpg to s3://mlbees/input/1226798.jpg
# upload: ./12452075.jpg to s3://mlbees/input/12452075.jpg
# upload: ./1233874.jpg to s3://mlbees/input/1233874.jpg
# upload: ./12759368.jpg to s3://mlbees/input/12759368.jpg
# upload: ./12696936.jpg to s3://mlbees/input/12696936.jpg
# upload: ./12770815.jpg to s3://mlbees/input/12770815.jpg
# upload: ./1277788.jpg to s3://mlbees/input/1277788.jpg
# upload: ./12884707.jpg to s3://mlbees/input/12884707.jpg
# upload: ./12884927.jpg to s3://mlbees/input/12884927.jpg
# upload: ./129048.jpg to s3://mlbees/input/129048.jpg
# upload: ./12913742.jpg to s3://mlbees/input/12913742.jpg
# upload: ./12939357.jpg to s3://mlbees/input/12939357.jpg
# upload: ./12928376.jpg to s3://mlbees/input/12928376.jpg
# upload: ./12993998.jpg to s3://mlbees/input/12993998.jpg
# upload: ./13019032.jpg to s3://mlbees/input/13019032.jpg
# upload: ./1303310.jpg to s3://mlbees/input/1303310.jpg
# upload: ./13062029.jpg to s3://mlbees/input/13062029.jpg
# upload: ./13272553.jpg to s3://mlbees/input/13272553.jpg
# upload: ./13273620.jpg to s3://mlbees/input/13273620.jpg
# upload: ./13273626.jpg to s3://mlbees/input/13273626.jpg
# upload: ./13441895.jpg to s3://mlbees/input/13441895.jpg
# upload: ./13373012.jpg to s3://mlbees/input/13373012.jpg
# upload: ./13068600.jpg to s3://mlbees/input/13068600.jpg
# upload: ./13428524.jpg to s3://mlbees/input/13428524.jpg
# upload: ./1341535.jpg to s3://mlbees/input/1341535.jpg
# upload: ./1348286.jpg to s3://mlbees/input/1348286.jpg
# upload: ./13486009.jpg to s3://mlbees/input/13486009.jpg
# upload: ./13521479.jpg to s3://mlbees/input/13521479.jpg
# upload: ./13496549.jpg to s3://mlbees/input/13496549.jpg
# upload: ./13570276.jpg to s3://mlbees/input/13570276.jpg
# upload: ./13732698.jpg to s3://mlbees/input/13732698.jpg
# upload: ./1382920.jpg to s3://mlbees/input/1382920.jpg
# upload: ./13601043.jpg to s3://mlbees/input/13601043.jpg
# upload: ./13830001.jpg to s3://mlbees/input/13830001.jpg
# upload: ./13870264.jpg to s3://mlbees/input/13870264.jpg
# upload: ./13876315.jpg to s3://mlbees/input/13876315.jpg
# upload: ./13889661.jpg to s3://mlbees/input/13889661.jpg
# upload: ./1385268.jpg to s3://mlbees/input/1385268.jpg
# upload: ./13998689.jpg to s3://mlbees/input/13998689.jpg
# upload: ./1402452.jpg to s3://mlbees/input/1402452.jpg
# upload: ./14243346.jpg to s3://mlbees/input/14243346.jpg
# upload: ./14181278.jpg to s3://mlbees/input/14181278.jpg
# upload: ./14313481.jpg to s3://mlbees/input/14313481.jpg
# upload: ./14243427.jpg to s3://mlbees/input/14243427.jpg
# upload: ./14350171.jpg to s3://mlbees/input/14350171.jpg
# upload: ./14519274.jpg to s3://mlbees/input/14519274.jpg
# upload: ./14412291.jpg to s3://mlbees/input/14412291.jpg
# upload: ./1458551.jpg to s3://mlbees/input/1458551.jpg
# upload: ./14814253.jpg to s3://mlbees/input/14814253.jpg
# upload: ./14597891.jpg to s3://mlbees/input/14597891.jpg
# upload: ./15028714.jpg to s3://mlbees/input/15028714.jpg
# upload: ./15076485.jpg to s3://mlbees/input/15076485.jpg
# upload: ./14816563.jpg to s3://mlbees/input/14816563.jpg
# upload: ./15119215.jpg to s3://mlbees/input/15119215.jpg
# upload: ./15086353.jpg to s3://mlbees/input/15086353.jpg
# upload: ./15119232.jpg to s3://mlbees/input/15119232.jpg
# upload: ./15146992.jpg to s3://mlbees/input/15146992.jpg
# upload: ./15182038.jpg to s3://mlbees/input/15182038.jpg
# upload: ./15140063.jpg to s3://mlbees/input/15140063.jpg
# upload: ./1522678.jpg to s3://mlbees/input/1522678.jpg
# upload: ./15304016.jpg to s3://mlbees/input/15304016.jpg
# upload: ./15182039.jpg to s3://mlbees/input/15182039.jpg
# upload: ./15305778.jpg to s3://mlbees/input/15305778.jpg
# upload: ./15338029.jpg to s3://mlbees/input/15338029.jpg
# upload: ./15459727.jpg to s3://mlbees/input/15459727.jpg
# upload: ./15328335.jpg to s3://mlbees/input/15328335.jpg
# upload: ./15620821.jpg to s3://mlbees/input/15620821.jpg
# upload: ./15672860.jpg to s3://mlbees/input/15672860.jpg
# upload: ./15469914.jpg to s3://mlbees/input/15469914.jpg
# upload: ./15688300.jpg to s3://mlbees/input/15688300.jpg
# upload: ./15754680.jpg to s3://mlbees/input/15754680.jpg
# upload: ./15709038.jpg to s3://mlbees/input/15709038.jpg
# upload: ./15769251.jpg to s3://mlbees/input/15769251.jpg
# upload: ./15793906.jpg to s3://mlbees/input/15793906.jpg
# upload: ./15970434.jpg to s3://mlbees/input/15970434.jpg
# upload: ./15932759.jpg to s3://mlbees/input/15932759.jpg
# upload: ./16152609.jpg to s3://mlbees/input/16152609.jpg
# upload: ./16184070.jpg to s3://mlbees/input/16184070.jpg
# upload: ./16218403.jpg to s3://mlbees/input/16218403.jpg
# upload: ./16296603.jpg to s3://mlbees/input/16296603.jpg
# upload: ./1636555.jpg to s3://mlbees/input/1636555.jpg
# upload: ./1621891.jpg to s3://mlbees/input/1621891.jpg
# upload: ./16459302.jpg to s3://mlbees/input/16459302.jpg
# upload: ./16469176.jpg to s3://mlbees/input/16469176.jpg
# upload: ./16562561.jpg to s3://mlbees/input/16562561.jpg
# upload: ./16630340.jpg to s3://mlbees/input/16630340.jpg
# upload: ./16661995.jpg to s3://mlbees/input/16661995.jpg
# upload: ./16689677.jpg to s3://mlbees/input/16689677.jpg
# upload: ./16724633.jpg to s3://mlbees/input/16724633.jpg
# upload: ./16832956.jpg to s3://mlbees/input/16832956.jpg
# upload: ./16993962.jpg to s3://mlbees/input/16993962.jpg
# upload: ./1686330.jpg to s3://mlbees/input/1686330.jpg
# upload: ./16900739.jpg to s3://mlbees/input/16900739.jpg
# upload: ./16996647.jpg to s3://mlbees/input/16996647.jpg
# upload: ./17067137.jpg to s3://mlbees/input/17067137.jpg
# upload: ./17179096.jpg to s3://mlbees/input/17179096.jpg
# upload: ./17283792.jpg to s3://mlbees/input/17283792.jpg
# upload: ./17318228.jpg to s3://mlbees/input/17318228.jpg
# upload: ./17392224.jpg to s3://mlbees/input/17392224.jpg
# upload: ./17343330.jpg to s3://mlbees/input/17343330.jpg
# upload: ./17375861.jpg to s3://mlbees/input/17375861.jpg
# upload: ./1745127.jpg to s3://mlbees/input/1745127.jpg
# upload: ./1743337.jpg to s3://mlbees/input/1743337.jpg
# upload: ./1750527.jpg to s3://mlbees/input/1750527.jpg
# upload: ./17516125.jpg to s3://mlbees/input/17516125.jpg
# upload: ./17582620.jpg to s3://mlbees/input/17582620.jpg
# upload: ./1753721.jpg to s3://mlbees/input/1753721.jpg
# upload: ./17735276.jpg to s3://mlbees/input/17735276.jpg
# upload: ./17752165.jpg to s3://mlbees/input/17752165.jpg
# upload: ./1783055.jpg to s3://mlbees/input/1783055.jpg
# upload: ./176974.jpg to s3://mlbees/input/176974.jpg
# upload: ./17852751.jpg to s3://mlbees/input/17852751.jpg
# upload: ./17846870.jpg to s3://mlbees/input/17846870.jpg
# upload: ./179635.jpg to s3://mlbees/input/179635.jpg
# upload: ./17988156.jpg to s3://mlbees/input/17988156.jpg
# upload: ./18072260.jpg to s3://mlbees/input/18072260.jpg
# upload: ./18172239.jpg to s3://mlbees/input/18172239.jpg
# upload: ./1827596.jpg to s3://mlbees/input/1827596.jpg
# upload: ./1839890.jpg to s3://mlbees/input/1839890.jpg
# upload: ./1866760.jpg to s3://mlbees/input/1866760.jpg
# upload: ./18465677.jpg to s3://mlbees/input/18465677.jpg
# upload: ./1870860.jpg to s3://mlbees/input/1870860.jpg
# upload: ./18741153.jpg to s3://mlbees/input/18741153.jpg
# upload: ./1877849.jpg to s3://mlbees/input/1877849.jpg
# upload: ./18826464.jpg to s3://mlbees/input/18826464.jpg
# upload: ./18900641.jpg to s3://mlbees/input/18900641.jpg
# upload: ./1897820.jpg to s3://mlbees/input/1897820.jpg
# upload: ./1897865.jpg to s3://mlbees/input/1897865.jpg
# upload: ./19101401.jpg to s3://mlbees/input/19101401.jpg
# upload: ./1921591.jpg to s3://mlbees/input/1921591.jpg
# upload: ./19341453.jpg to s3://mlbees/input/19341453.jpg
# upload: ./19342092.jpg to s3://mlbees/input/19342092.jpg
# upload: ./19449618.jpg to s3://mlbees/input/19449618.jpg
# upload: ./19546072.jpg to s3://mlbees/input/19546072.jpg
# upload: ./19576035.jpg to s3://mlbees/input/19576035.jpg
# upload: ./19593060.jpg to s3://mlbees/input/19593060.jpg
# upload: ./1960062.jpg to s3://mlbees/input/1960062.jpg
# upload: ./196127.jpg to s3://mlbees/input/196127.jpg
# upload: ./196158.jpg to s3://mlbees/input/196158.jpg
# upload: ./19908086.jpg to s3://mlbees/input/19908086.jpg
# upload: ./19899015.jpg to s3://mlbees/input/19899015.jpg
# upload: ./19774688.jpg to s3://mlbees/input/19774688.jpg
# upload: ./19916078.jpg to s3://mlbees/input/19916078.jpg
# upload: ./19849199.jpg to s3://mlbees/input/19849199.jpg
# upload: ./20066763.jpg to s3://mlbees/input/20066763.jpg
# upload: ./20204304.jpg to s3://mlbees/input/20204304.jpg
# upload: ./20259814.jpg to s3://mlbees/input/20259814.jpg
# upload: ./2008988.jpg to s3://mlbees/input/2008988.jpg
# upload: ./20268599.jpg to s3://mlbees/input/20268599.jpg
# upload: ./20311696.jpg to s3://mlbees/input/20311696.jpg
# upload: ./20369982.jpg to s3://mlbees/input/20369982.jpg
# upload: ./20375587.jpg to s3://mlbees/input/20375587.jpg
# upload: ./20371916.jpg to s3://mlbees/input/20371916.jpg
# upload: ./20431306.jpg to s3://mlbees/input/20431306.jpg
# upload: ./20438918.jpg to s3://mlbees/input/20438918.jpg
# upload: ./20517772.jpg to s3://mlbees/input/20517772.jpg
# upload: ./20473705.jpg to s3://mlbees/input/20473705.jpg
# upload: ./20738988.jpg to s3://mlbees/input/20738988.jpg
# upload: ./20773486.jpg to s3://mlbees/input/20773486.jpg
# upload: ./20786438.jpg to s3://mlbees/input/20786438.jpg
# upload: ./20864718.jpg to s3://mlbees/input/20864718.jpg
# upload: ./21136493.jpg to s3://mlbees/input/21136493.jpg
# upload: ./21065816.jpg to s3://mlbees/input/21065816.jpg
# upload: ./21148.jpg to s3://mlbees/input/21148.jpg
# upload: ./21163231.jpg to s3://mlbees/input/21163231.jpg
# upload: ./21182718.jpg to s3://mlbees/input/21182718.jpg
# upload: ./21198327.jpg to s3://mlbees/input/21198327.jpg
# upload: ./21238683.jpg to s3://mlbees/input/21238683.jpg
# upload: ./21288228.jpg to s3://mlbees/input/21288228.jpg
# upload: ./21301169.jpg to s3://mlbees/input/21301169.jpg
# upload: ./21291703.jpg to s3://mlbees/input/21291703.jpg
# upload: ./21309124.jpg to s3://mlbees/input/21309124.jpg
# upload: ./21524271.jpg to s3://mlbees/input/21524271.jpg
# upload: ./21483683.jpg to s3://mlbees/input/21483683.jpg
# upload: ./21539887.jpg to s3://mlbees/input/21539887.jpg
# upload: ./21572388.jpg to s3://mlbees/input/21572388.jpg
# upload: ./21605658.jpg to s3://mlbees/input/21605658.jpg
# upload: ./21669777.jpg to s3://mlbees/input/21669777.jpg
# upload: ./21793650.jpg to s3://mlbees/input/21793650.jpg
# upload: ./21874075.jpg to s3://mlbees/input/21874075.jpg
# upload: ./21923539.jpg to s3://mlbees/input/21923539.jpg
# upload: ./21904310.jpg to s3://mlbees/input/21904310.jpg
# upload: ./22036101.jpg to s3://mlbees/input/22036101.jpg
# upload: ./22147209.jpg to s3://mlbees/input/22147209.jpg
# upload: ./22214959.jpg to s3://mlbees/input/22214959.jpg
# upload: ./22315276.jpg to s3://mlbees/input/22315276.jpg
# upload: ./22351101.jpg to s3://mlbees/input/22351101.jpg
# upload: ./228752.jpg to s3://mlbees/input/228752.jpg
# upload: ./2346456.jpg to s3://mlbees/input/2346456.jpg
# upload: ./2371862.jpg to s3://mlbees/input/2371862.jpg
# upload: ./2412967.jpg to s3://mlbees/input/2412967.jpg
# upload: ./2655909.jpg to s3://mlbees/input/2655909.jpg
# upload: ./2351735.jpg to s3://mlbees/input/2351735.jpg
# upload: ./2619775.jpg to s3://mlbees/input/2619775.jpg
# upload: ./2665436.jpg to s3://mlbees/input/2665436.jpg
# upload: ./2742778.jpg to s3://mlbees/input/2742778.jpg
# upload: ./27027.jpg to s3://mlbees/input/27027.jpg
# upload: ./2742941.jpg to s3://mlbees/input/2742941.jpg
# upload: ./2775464.jpg to s3://mlbees/input/2775464.jpg
# upload: ./2788781.jpg to s3://mlbees/input/2788781.jpg
# upload: ./2810169.jpg to s3://mlbees/input/2810169.jpg
# upload: ./2815585.jpg to s3://mlbees/input/2815585.jpg
# upload: ./2869125.jpg to s3://mlbees/input/2869125.jpg
# upload: ./2837296.jpg to s3://mlbees/input/2837296.jpg
# upload: ./2824624.jpg to s3://mlbees/input/2824624.jpg
# upload: ./2865161.jpg to s3://mlbees/input/2865161.jpg
# upload: ./2840352.jpg to s3://mlbees/input/2840352.jpg
# upload: ./2878300.jpg to s3://mlbees/input/2878300.jpg
# upload: ./2914669.jpg to s3://mlbees/input/2914669.jpg
# upload: ./2929786.jpg to s3://mlbees/input/2929786.jpg
# upload: ./2934204.jpg to s3://mlbees/input/2934204.jpg
# upload: ./2944554.jpg to s3://mlbees/input/2944554.jpg
# upload: ./293567.jpg to s3://mlbees/input/293567.jpg
# upload: ./2985479.jpg to s3://mlbees/input/2985479.jpg
# upload: ./2979701.jpg to s3://mlbees/input/2979701.jpg
# upload: ./2947798.jpg to s3://mlbees/input/2947798.jpg
# upload: ./2946744.jpg to s3://mlbees/input/2946744.jpg
# upload: ./2951747.jpg to s3://mlbees/input/2951747.jpg
# upload: ./2946350.jpg to s3://mlbees/input/2946350.jpg
# upload: ./3009327.jpg to s3://mlbees/input/3009327.jpg
# upload: ./3086303.jpg to s3://mlbees/input/3086303.jpg
# upload: ./3018628.jpg to s3://mlbees/input/3018628.jpg
# upload: ./3051366.jpg to s3://mlbees/input/3051366.jpg
# upload: ./3117194.jpg to s3://mlbees/input/3117194.jpg
# upload: ./310239.jpg to s3://mlbees/input/310239.jpg
# upload: ./3092738.jpg to s3://mlbees/input/3092738.jpg
# upload: ./3122440.jpg to s3://mlbees/input/3122440.jpg
# upload: ./2995132.jpg to s3://mlbees/input/2995132.jpg
# upload: ./32131.jpg to s3://mlbees/input/32131.jpg
# upload: ./3216956.jpg to s3://mlbees/input/3216956.jpg
# upload: ./3233883.jpg to s3://mlbees/input/3233883.jpg
# upload: ./3234797.jpg to s3://mlbees/input/3234797.jpg
# upload: ./3257087.jpg to s3://mlbees/input/3257087.jpg
# upload: ./3236105.jpg to s3://mlbees/input/3236105.jpg
# upload: ./3312871.jpg to s3://mlbees/input/3312871.jpg
# upload: ./3280744.jpg to s3://mlbees/input/3280744.jpg
# upload: ./3330424.jpg to s3://mlbees/input/3330424.jpg
# upload: ./3330409.jpg to s3://mlbees/input/3330409.jpg
# upload: ./3345827.jpg to s3://mlbees/input/3345827.jpg
# upload: ./3337655.jpg to s3://mlbees/input/3337655.jpg
# upload: ./3345411.jpg to s3://mlbees/input/3345411.jpg
# upload: ./3061550.jpg to s3://mlbees/input/3061550.jpg
# upload: ./3362033.jpg to s3://mlbees/input/3362033.jpg
# upload: ./3394412.jpg to s3://mlbees/input/3394412.jpg
# upload: ./343132.jpg to s3://mlbees/input/343132.jpg
# upload: ./3452888.jpg to s3://mlbees/input/3452888.jpg
# upload: ./3441057.jpg to s3://mlbees/input/3441057.jpg
# upload: ./3481031.jpg to s3://mlbees/input/3481031.jpg
# upload: ./3498814.jpg to s3://mlbees/input/3498814.jpg
# upload: ./3506356.jpg to s3://mlbees/input/3506356.jpg
# upload: ./3519808.jpg to s3://mlbees/input/3519808.jpg
# upload: ./3585185.jpg to s3://mlbees/input/3585185.jpg
# upload: ./3571648.jpg to s3://mlbees/input/3571648.jpg
# upload: ./3144243.jpg to s3://mlbees/input/3144243.jpg
# upload: ./3125305.jpg to s3://mlbees/input/3125305.jpg
# upload: ./3379360.jpg to s3://mlbees/input/3379360.jpg
# upload: ./3597137.jpg to s3://mlbees/input/3597137.jpg
# upload: ./3185105.jpg to s3://mlbees/input/3185105.jpg
# upload: ./3619917.jpg to s3://mlbees/input/3619917.jpg
# upload: ./3633945.jpg to s3://mlbees/input/3633945.jpg
# upload: ./3640343.jpg to s3://mlbees/input/3640343.jpg
# upload: ./3667381.jpg to s3://mlbees/input/3667381.jpg
# upload: ./3645749.jpg to s3://mlbees/input/3645749.jpg
# upload: ./3680409.jpg to s3://mlbees/input/3680409.jpg
# upload: ./3687783.jpg to s3://mlbees/input/3687783.jpg
# upload: ./3701197.jpg to s3://mlbees/input/3701197.jpg
# upload: ./3729432.jpg to s3://mlbees/input/3729432.jpg
# upload: ./3732759.jpg to s3://mlbees/input/3732759.jpg
# upload: ./3745384.jpg to s3://mlbees/input/3745384.jpg
# upload: ./376521.jpg to s3://mlbees/input/376521.jpg
# upload: ./3772325.jpg to s3://mlbees/input/3772325.jpg
# upload: ./3787344.jpg to s3://mlbees/input/3787344.jpg
# upload: ./3875104.jpg to s3://mlbees/input/3875104.jpg
# upload: ./3879464.jpg to s3://mlbees/input/3879464.jpg
# upload: ./3895733.jpg to s3://mlbees/input/3895733.jpg
# upload: ./3885297.jpg to s3://mlbees/input/3885297.jpg
# upload: ./3898660.jpg to s3://mlbees/input/3898660.jpg
# upload: ./3927527.jpg to s3://mlbees/input/3927527.jpg
# upload: ./3899906.jpg to s3://mlbees/input/3899906.jpg
# upload: ./397780.jpg to s3://mlbees/input/397780.jpg
# upload: ./3977830.jpg to s3://mlbees/input/3977830.jpg
# upload: ./3992659.jpg to s3://mlbees/input/3992659.jpg
# upload: ./4064592.jpg to s3://mlbees/input/4064592.jpg
# upload: ./4064563.jpg to s3://mlbees/input/4064563.jpg
# upload: ./4028470.jpg to s3://mlbees/input/4028470.jpg
# upload: ./4082878.jpg to s3://mlbees/input/4082878.jpg
# upload: ./4165149.jpg to s3://mlbees/input/4165149.jpg
# upload: ./4174616.jpg to s3://mlbees/input/4174616.jpg
# upload: ./4187599.jpg to s3://mlbees/input/4187599.jpg
# upload: ./418761.jpg to s3://mlbees/input/418761.jpg
# upload: ./4193744.jpg to s3://mlbees/input/4193744.jpg
# upload: ./4095217.jpg to s3://mlbees/input/4095217.jpg
# upload: ./4210740.jpg to s3://mlbees/input/4210740.jpg
# upload: ./4309307.jpg to s3://mlbees/input/4309307.jpg
# upload: ./4311470.jpg to s3://mlbees/input/4311470.jpg
# upload: ./4235263.jpg to s3://mlbees/input/4235263.jpg
# upload: ./4311471.jpg to s3://mlbees/input/4311471.jpg
# upload: ./441431.jpg to s3://mlbees/input/441431.jpg
# upload: ./4415867.jpg to s3://mlbees/input/4415867.jpg
# upload: ./4459251.jpg to s3://mlbees/input/4459251.jpg
# upload: ./4603320.jpg to s3://mlbees/input/4603320.jpg
# upload: ./458759.jpg to s3://mlbees/input/458759.jpg
# upload: ./4609029.jpg to s3://mlbees/input/4609029.jpg
# upload: ./465561.jpg to s3://mlbees/input/465561.jpg
# upload: ./466273.jpg to s3://mlbees/input/466273.jpg
# upload: ./4628101.jpg to s3://mlbees/input/4628101.jpg
# upload: ./4754331.jpg to s3://mlbees/input/4754331.jpg
# upload: ./4797829.jpg to s3://mlbees/input/4797829.jpg
# upload: ./4797846.jpg to s3://mlbees/input/4797846.jpg
# upload: ./4797845.jpg to s3://mlbees/input/4797845.jpg
# upload: ./4996293.jpg to s3://mlbees/input/4996293.jpg
# upload: ./5037168.jpg to s3://mlbees/input/5037168.jpg
# upload: ./4888045.jpg to s3://mlbees/input/4888045.jpg
# upload: ./5047459.jpg to s3://mlbees/input/5047459.jpg
# upload: ./5100385.jpg to s3://mlbees/input/5100385.jpg
# upload: ./5243865.jpg to s3://mlbees/input/5243865.jpg
# upload: ./5254018.jpg to s3://mlbees/input/5254018.jpg
# upload: ./5287617.jpg to s3://mlbees/input/5287617.jpg
# upload: ./5295321.jpg to s3://mlbees/input/5295321.jpg
# upload: ./534684.jpg to s3://mlbees/input/534684.jpg
# upload: ./534926.jpg to s3://mlbees/input/534926.jpg
# upload: ./5397717.jpg to s3://mlbees/input/5397717.jpg
# upload: ./5393274.jpg to s3://mlbees/input/5393274.jpg
# upload: ./5474129.jpg to s3://mlbees/input/5474129.jpg
# upload: ./5405024.jpg to s3://mlbees/input/5405024.jpg
# upload: ./5230479.jpg to s3://mlbees/input/5230479.jpg
# upload: ./5476166.jpg to s3://mlbees/input/5476166.jpg
# upload: ./548303.jpg to s3://mlbees/input/548303.jpg
# upload: ./548320.jpg to s3://mlbees/input/548320.jpg
# upload: ./5520144.jpg to s3://mlbees/input/5520144.jpg
# upload: ./5535715.jpg to s3://mlbees/input/5535715.jpg
# upload: ./5544509.jpg to s3://mlbees/input/5544509.jpg
# upload: ./5544510.jpg to s3://mlbees/input/5544510.jpg
# upload: ./5592625.jpg to s3://mlbees/input/5592625.jpg
# upload: ./5602977.jpg to s3://mlbees/input/5602977.jpg
# upload: ./5702855.jpg to s3://mlbees/input/5702855.jpg
# upload: ./5665282.jpg to s3://mlbees/input/5665282.jpg
# upload: ./570456.jpg to s3://mlbees/input/570456.jpg
# upload: ./5704624.jpg to s3://mlbees/input/5704624.jpg
# upload: ./5709073.jpg to s3://mlbees/input/5709073.jpg
# upload: ./5717250.jpg to s3://mlbees/input/5717250.jpg
# upload: ./5726711.jpg to s3://mlbees/input/5726711.jpg
# upload: ./5735703.jpg to s3://mlbees/input/5735703.jpg
# upload: ./579067.jpg to s3://mlbees/input/579067.jpg
# upload: ./573816.jpg to s3://mlbees/input/573816.jpg
# upload: ./5800240.jpg to s3://mlbees/input/5800240.jpg
# upload: ./5912119.jpg to s3://mlbees/input/5912119.jpg
# upload: ./5870657.jpg to s3://mlbees/input/5870657.jpg
# upload: ./591394.jpg to s3://mlbees/input/591394.jpg
# upload: ./5989105.jpg to s3://mlbees/input/5989105.jpg
# upload: ./599865.jpg to s3://mlbees/input/599865.jpg
# upload: ./603031.jpg to s3://mlbees/input/603031.jpg
# upload: ./6044995.jpg to s3://mlbees/input/6044995.jpg
# upload: ./609711.jpg to s3://mlbees/input/609711.jpg
# upload: ./6187512.jpg to s3://mlbees/input/6187512.jpg
# upload: ./6381998.jpg to s3://mlbees/input/6381998.jpg
# upload: ./6296565.jpg to s3://mlbees/input/6296565.jpg
# upload: ./6458782.jpg to s3://mlbees/input/6458782.jpg
# upload: ./6415127.jpg to s3://mlbees/input/6415127.jpg
# upload: ./6415462.jpg to s3://mlbees/input/6415462.jpg
# upload: ./6507610.jpg to s3://mlbees/input/6507610.jpg
# upload: ./653176.jpg to s3://mlbees/input/653176.jpg
# upload: ./6576634.jpg to s3://mlbees/input/6576634.jpg
# upload: ./6586221.jpg to s3://mlbees/input/6586221.jpg
# upload: ./6675259.jpg to s3://mlbees/input/6675259.jpg
# upload: ./6729805.jpg to s3://mlbees/input/6729805.jpg
# upload: ./6797780.jpg to s3://mlbees/input/6797780.jpg
# upload: ./6814980.jpg to s3://mlbees/input/6814980.jpg
# upload: ./6894165.jpg to s3://mlbees/input/6894165.jpg
# upload: ./6815391.jpg to s3://mlbees/input/6815391.jpg
# upload: ./6902498.jpg to s3://mlbees/input/6902498.jpg
# upload: ./6917834.jpg to s3://mlbees/input/6917834.jpg
# upload: ./6943059.jpg to s3://mlbees/input/6943059.jpg
# upload: ./6948902.jpg to s3://mlbees/input/6948902.jpg
# upload: ./6967241.jpg to s3://mlbees/input/6967241.jpg
# upload: ./7069816.jpg to s3://mlbees/input/7069816.jpg
# upload: ./7024032.jpg to s3://mlbees/input/7024032.jpg
# upload: ./7094891.jpg to s3://mlbees/input/7094891.jpg
# upload: ./7102825.jpg to s3://mlbees/input/7102825.jpg
# upload: ./7135222.jpg to s3://mlbees/input/7135222.jpg
# upload: ./7149449.jpg to s3://mlbees/input/7149449.jpg
# upload: ./712170.jpg to s3://mlbees/input/712170.jpg
# upload: ./7172247.jpg to s3://mlbees/input/7172247.jpg
# upload: ./7193173.jpg to s3://mlbees/input/7193173.jpg
# upload: ./7177822.jpg to s3://mlbees/input/7177822.jpg
# upload: ./7202668.jpg to s3://mlbees/input/7202668.jpg
# upload: ./7263703.jpg to s3://mlbees/input/7263703.jpg
# upload: ./7351837.jpg to s3://mlbees/input/7351837.jpg
# upload: ./7301708.jpg to s3://mlbees/input/7301708.jpg
# upload: ./7363261.jpg to s3://mlbees/input/7363261.jpg
# upload: ./7253464.jpg to s3://mlbees/input/7253464.jpg
# upload: ./7232396.jpg to s3://mlbees/input/7232396.jpg
# upload: ./7399034.jpg to s3://mlbees/input/7399034.jpg
# upload: ./7403704.jpg to s3://mlbees/input/7403704.jpg
# upload: ./7411702.jpg to s3://mlbees/input/7411702.jpg
# upload: ./7433564.jpg to s3://mlbees/input/7433564.jpg
# upload: ./7535421.jpg to s3://mlbees/input/7535421.jpg
# upload: ./7552984.jpg to s3://mlbees/input/7552984.jpg
# upload: ./7465403.jpg to s3://mlbees/input/7465403.jpg
# upload: ./7560100.jpg to s3://mlbees/input/7560100.jpg
# upload: ./7563820.jpg to s3://mlbees/input/7563820.jpg
# upload: ./7606249.jpg to s3://mlbees/input/7606249.jpg
# upload: ./7669887.jpg to s3://mlbees/input/7669887.jpg
# upload: ./7731620.jpg to s3://mlbees/input/7731620.jpg
# upload: ./7749622.jpg to s3://mlbees/input/7749622.jpg
# upload: ./7727530.jpg to s3://mlbees/input/7727530.jpg
# upload: ./7799668.jpg to s3://mlbees/input/7799668.jpg
# upload: ./7799671.jpg to s3://mlbees/input/7799671.jpg
# upload: ./7775938.jpg to s3://mlbees/input/7775938.jpg
# upload: ./7864547.jpg to s3://mlbees/input/7864547.jpg
# upload: ./7813343.jpg to s3://mlbees/input/7813343.jpg
# upload: ./7895679.jpg to s3://mlbees/input/7895679.jpg
# upload: ./7917924.jpg to s3://mlbees/input/7917924.jpg
# upload: ./7969257.jpg to s3://mlbees/input/7969257.jpg
# upload: ./8034632.jpg to s3://mlbees/input/8034632.jpg
# upload: ./8034635.jpg to s3://mlbees/input/8034635.jpg
# upload: ./8011544.jpg to s3://mlbees/input/8011544.jpg
# upload: ./8050677.jpg to s3://mlbees/input/8050677.jpg
# upload: ./811725.jpg to s3://mlbees/input/811725.jpg
# upload: ./8210622.jpg to s3://mlbees/input/8210622.jpg
# upload: ./8215592.jpg to s3://mlbees/input/8215592.jpg
# upload: ./8395363.jpg to s3://mlbees/input/8395363.jpg
# upload: ./8413023.jpg to s3://mlbees/input/8413023.jpg
# upload: ./8405434.jpg to s3://mlbees/input/8405434.jpg
# upload: ./8421746.jpg to s3://mlbees/input/8421746.jpg
# upload: ./8624894.jpg to s3://mlbees/input/8624894.jpg
# upload: ./8644641.jpg to s3://mlbees/input/8644641.jpg
# upload: ./8520341.jpg to s3://mlbees/input/8520341.jpg
# upload: ./8644268.jpg to s3://mlbees/input/8644268.jpg
# upload: ./8646366.jpg to s3://mlbees/input/8646366.jpg
# upload: ./8646384.jpg to s3://mlbees/input/8646384.jpg
# upload: ./8645016.jpg to s3://mlbees/input/8645016.jpg
# upload: ./8681903.jpg to s3://mlbees/input/8681903.jpg
# upload: ./8722712.jpg to s3://mlbees/input/8722712.jpg
# upload: ./8760942.jpg to s3://mlbees/input/8760942.jpg
# upload: ./8699605.jpg to s3://mlbees/input/8699605.jpg
# upload: ./8813739.jpg to s3://mlbees/input/8813739.jpg
# upload: ./882548.jpg to s3://mlbees/input/882548.jpg
# upload: ./8835014.jpg to s3://mlbees/input/8835014.jpg
# upload: ./8855115.jpg to s3://mlbees/input/8855115.jpg
# upload: ./8941833.jpg to s3://mlbees/input/8941833.jpg
# upload: ./8887797.jpg to s3://mlbees/input/8887797.jpg
# upload: ./8943708.jpg to s3://mlbees/input/8943708.jpg
# upload: ./8993245.jpg to s3://mlbees/input/8993245.jpg
# upload: ./9017964.jpg to s3://mlbees/input/9017964.jpg
# upload: ./9128036.jpg to s3://mlbees/input/9128036.jpg
# upload: ./9019418.jpg to s3://mlbees/input/9019418.jpg
# upload: ./9291964.jpg to s3://mlbees/input/9291964.jpg
# upload: ./9328246.jpg to s3://mlbees/input/9328246.jpg
# upload: ./9366274.jpg to s3://mlbees/input/9366274.jpg
# upload: ./9542264.jpg to s3://mlbees/input/9542264.jpg
# upload: ./9530124.jpg to s3://mlbees/input/9530124.jpg
# upload: ./9637165.jpg to s3://mlbees/input/9637165.jpg
# upload: ./9765741.jpg to s3://mlbees/input/9765741.jpg
# upload: ./9543188.jpg to s3://mlbees/input/9543188.jpg
# upload: ./9787032.jpg to s3://mlbees/input/9787032.jpg

# %% [markdown]
# ## Labeling with SageMaker Ground Truth <a name="groundtruth"></a>

# %% [markdown]
# Now, we are ready to run your first labeling with Amazon SageMaker Ground Truth. Follow the steps shown in the recording.
#
# When specifying information needed to configure the labeling UI tool, use the following information:
#
# - Brief task description: _"Draw a bounding box around the bee in this image."_
# - Labels: _"bee"_
# - Good example description: _"bounding box includes all visible parts of the insect - legs, antennae, etc."_
# - Good example image: https://s3.us-west-2.amazonaws.com/aws-tc-largeobjects/DIG-TF-200-MLBEES-10-EN/bee-good-5535715.jpg
# - Bad example description: _"bounding box is too big and/or excludes some visible parts of the insect"_
# - Bad example image: https://s3.us-west-2.amazonaws.com/aws-tc-largeobjects/DIG-TF-200-MLBEES-10-EN/bee-bad-5535715.jpg

# %% [markdown]
# ## Reviewing labeling results
# <a name="reviewing"></a>
#
# After the labeling job has completed, we can see the results of image annotations right in the SageMaker console itself. The console displays each image as well as the bounding boxes around the bees that were drawn by human labelers.
#
# At the same time we can examine the results in the so-called augmented manifest file that was generated. Let's download and examine the manifest file.

# %%
# Enter the name of your job here
labeling_job_name = 'bees-sample'

import boto3
client = boto3.client('sagemaker')

#s3_output = client.describe_labeling_job(LabelingJobName=labeling_job_name)['OutputConfig']['S3OutputPath'] + labeling_job_name
augmented_manifest_url = f's3://mlbees/output/bees-sample/manifests/output/output.manifest'

import os
import shutil

try:
    os.makedirs('od_output_data/', exist_ok=False)
except FileExistsError:
    shutil.rmtree('od_output_data/')

# now download the augmented manifest file and display first 3 lines
# !aws s3 cp $augmented_manifest_url od_output_data/
augmented_manifest_file = 'od_output_data/output.manifest'
# !head -3 $augmented_manifest_file
# Out:
# download: s3://mlbees/output/bees-sample/manifests/output/output.manifest to od_output_data/output.manifest
# {"source-ref":"s3://mlbees/input/10299519.jpg","bees-sample":{"annotations":[{"class_id":0,"width":148,"top":116,"height":164,"left":87}],"image_size":[{"width":375,"depth":3,"height":500}]},"bees-sample-metadata":{"job-name":"labeling-job/bees-sample","class-map":{"0":"bee"},"human-annotated":"yes","objects":[{"confidence":0.09}],"creation-date":"2020-05-05T07:06:41.335133","type":"groundtruth/object-detection"}}
# {"source-ref":"s3://mlbees/input/11340084.jpg","bees-sample":{"annotations":[{"class_id":0,"width":261,"top":145,"height":225,"left":104}],"image_size":[{"width":500,"depth":3,"height":500}]},"bees-sample-metadata":{"job-name":"labeling-job/bees-sample","class-map":{"0":"bee"},"human-annotated":"yes","objects":[{"confidence":0.09}],"creation-date":"2020-05-05T07:07:46.341276","type":"groundtruth/object-detection"}}
# {"source-ref":"s3://mlbees/input/15328335.jpg","bees-sample":{"annotations":[{"class_id":0,"width":37,"top":131,"height":31,"left":244}],"image_size":[{"width":500,"depth":3,"height":333}]},"bees-sample-metadata":{"job-name":"labeling-job/bees-sample","class-map":{"0":"bee"},"human-annotated":"yes","objects":[{"confidence":0.09}],"creation-date":"2020-05-05T07:07:46.358801","type":"groundtruth/object-detection"}}

# %% [markdown]
# Now let's plot all the annotated images. First, let's define a function that displays the local image file and draws over it the bounding boxes obtained via labeling.

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np
from itertools import cycle

def show_annotated_image(img_path, bboxes):
    im = np.array(Image.open(img_path), dtype=np.uint8)
    
    # Create figure and axes
    fig,ax = plt.subplots(1)

    # Display the image
    ax.imshow(im)

    colors = cycle(['r', 'g', 'b', 'y', 'c', 'm', 'k', 'w'])
    
    for bbox in bboxes:
        # Create a Rectangle patch
        rect = patches.Rectangle((bbox['left'],bbox['top']),bbox['width'],bbox['height'],linewidth=1,edgecolor=next(colors),facecolor='none')

        # Add the patch to the Axes
        ax.add_patch(rect)

    plt.show()

# %% [markdown]
# Next, read the augmented manifest (JSON lines format) line by line and display the first 10 images.

# %%
# !pip -q install --upgrade pip
# !pip -q install jsonlines
import jsonlines
from itertools import islice

with jsonlines.open(augmented_manifest_file, 'r') as reader:
    for desc in islice(reader, 10):
        img_url = desc['source-ref']
        img_file = os.path.basename(img_url)
        file_exists = os.path.isfile(img_file)

        bboxes = desc[labeling_job_name]['annotations']
        show_annotated_image(img_file, bboxes)

# %% [markdown]
# <a name='training'></a>
# ## Training an Object Detection Model
# We are now ready to use the labeled dataset in order to train a Machine Learning model using the SageMaker [built-in Object Detection algorithm](https://docs.aws.amazon.com/sagemaker/latest/dg/object-detection.html).
#
# For this, we would need to split the full labeled dataset into a training and a validation datasets. Out of the total of 500 images we are going to use 400 for training and 100 for validation. The algorithm will use the first one to train the model and the latter to estimate the accuracy of the model, trained so far. The augmented manifest file from the previously run full labeling job was included in the original zip archive as `output.manifest`.

# %%
import json

with jsonlines.open('output.manifest', 'r') as reader:
    lines = list(reader)
    # Shuffle data in place.
    np.random.shuffle(lines)
    
dataset_size = len(lines)
num_training_samples = round(dataset_size*0.8)

train_data = lines[:num_training_samples]
validation_data = lines[num_training_samples:]

augmented_manifest_filename_train = 'train.manifest'

with open(augmented_manifest_filename_train, 'w') as f:
    for line in train_data:
        f.write(json.dumps(line))
        f.write('\n')

augmented_manifest_filename_validation = 'validation.manifest'

with open(augmented_manifest_filename_validation, 'w') as f:
    for line in validation_data:
        f.write(json.dumps(line))
        f.write('\n')
        
print(f'training samples: {num_training_samples}, validation samples: {len(lines)-num_training_samples}')
# Out:
# training samples: 400, validation samples: 100

# %% [markdown]
# Next, let's upload the two manifest files to S3 in preparation for training. We will use the same bucket you created earlier.

# %%
pfx_training = PREFIX + '/training' if PREFIX else 'training'
# Defines paths for use in the training job request.
s3_train_data_path = 's3://{}/{}/{}'.format(BUCKET, pfx_training, augmented_manifest_filename_train)
s3_validation_data_path = 's3://{}/{}/{}'.format(BUCKET, pfx_training, augmented_manifest_filename_validation)

# !aws s3 cp train.manifest s3://$BUCKET/$pfx_training/
# !aws s3 cp validation.manifest s3://$BUCKET/$pfx_training/
# Out:
# upload: ./train.manifest to s3://mlbees/input/training/train.manifest
# upload: ./validation.manifest to s3://mlbees/input/training/validation.manifest

# %% [markdown]
# We are now ready to kick off the training. We will do it from the SageMaker console, but alternatively, you can just run this code in a new cell using SageMaker Python SDK:
# ### Code option

# %%
import time
import sagemaker

role = sagemaker.get_execution_role()
sess = sagemaker.Session()

training_image = sagemaker.amazon.amazon_estimator.get_image_uri(
    boto3.Session().region_name, 'object-detection', repo_version='latest')
s3_output_path = 's3://{}/{}/output'.format(BUCKET, pfx_training)

# Create unique job name
training_job_name = 'bees-detection-resnet'

training_params = \
    {
        "AlgorithmSpecification": {
            # NB. This is one of the named constants defined in the first cell.
            "TrainingImage": training_image,
            "TrainingInputMode": "Pipe"
        },
        "RoleArn": role,
        "OutputDataConfig": {
            "S3OutputPath": s3_output_path
        },
        "ResourceConfig": {
            "InstanceCount": 1,
            "InstanceType": "ml.p2.xlarge",
            "VolumeSizeInGB": 50
        },
        "TrainingJobName": training_job_name,
        "HyperParameters": {  # NB. These hyperparameters are at the user's discretion and are beyond the scope of this demo.
            "base_network": "resnet-50",
            "use_pretrained_model": "1",
            "num_classes": "1",
            "mini_batch_size": "1",
            "epochs": "100",
            "learning_rate": "0.001",
            "lr_scheduler_step": "",
            "lr_scheduler_factor": "0.1",
            "optimizer": "sgd",
            "momentum": "0.9",
            "weight_decay": "0.0005",
            "overlap_threshold": "0.5",
            "nms_threshold": "0.45",
            "image_shape": "300",
            "label_width": "350",
            "num_training_samples": str(num_training_samples)
        },
        "StoppingCondition": {
            "MaxRuntimeInSeconds": 86400
        },
        "InputDataConfig": [
            {
                "ChannelName": "train",
                "DataSource": {
                    "S3DataSource": {
                        "S3DataType": "AugmentedManifestFile",  # NB. Augmented Manifest
                        "S3Uri": s3_train_data_path,
                        "S3DataDistributionType": "FullyReplicated",
                        # NB. This must correspond to the JSON field names in your augmented manifest.
                        "AttributeNames": ['source-ref', 'bees-500']
                    }
                },
                "ContentType": "application/x-recordio",
                "RecordWrapperType": "RecordIO",
                "CompressionType": "None"
            },
            {
                "ChannelName": "validation",
                "DataSource": {
                    "S3DataSource": {
                        "S3DataType": "AugmentedManifestFile",  # NB. Augmented Manifest
                        "S3Uri": s3_validation_data_path,
                        "S3DataDistributionType": "FullyReplicated",
                        # NB. This must correspond to the JSON field names in your augmented manifest.
                        "AttributeNames": ['source-ref', 'bees-500']
                    }
                },
                "ContentType": "application/x-recordio",
                "RecordWrapperType": "RecordIO",
                "CompressionType": "None"
            }
        ]
    }

# Now we create the SageMaker training job.
client = boto3.client(service_name='sagemaker')
client.create_training_job(**training_params)

# Confirm that the training job has started
status = client.describe_training_job(TrainingJobName=training_job_name)['TrainingJobStatus']
print('Training job current status: {}'.format(status))

# %% [markdown]
# To check the progess of the training job, you can refresh the console or repeatedly evaluate the following cell. When the training job status reads `'Completed'`, move on to the next part of the tutorial.

# %%
##### REPLACE WITH YOUR OWN TRAINING JOB NAME
# In the above console screenshots the job name was 'bees-detection-resnet'.
# But if you used Python to kick off the training job,
# then 'training_job_name' is already set, so you can comment out the line below.
training_job_name = 'bees-training'
##### REPLACE WITH YOUR OWN TRAINING JOB NAME

training_info = client.describe_training_job(TrainingJobName=training_job_name)

print("Training job status: ", training_info['TrainingJobStatus'])
print("Secondary status: ", training_info['SecondaryStatus'])

# %% [markdown]
# <a name='review_training'></a>
#
# ## Review of Training Results

# %% [markdown]
# First, let's create the SageMaker model out of model artifacts

# %%
import time
timestamp = time.strftime('-%Y-%m-%d-%H-%M-%S', time.gmtime())
model_name = training_job_name + '-model' + timestamp

training_image = training_info['AlgorithmSpecification']['TrainingImage']
model_data = training_info['ModelArtifacts']['S3ModelArtifacts']

primary_container = {
    'Image': training_image,
    'ModelDataUrl': model_data,
}

from sagemaker import get_execution_role

role = get_execution_role()

create_model_response = client.create_model(
    ModelName = model_name,
    ExecutionRoleArn = role,
    PrimaryContainer = primary_container)

print(create_model_response['ModelArn'])

# %%
timestamp = time.strftime('-%Y-%m-%d-%H-%M-%S', time.gmtime())
endpoint_config_name = training_job_name + '-epc' + timestamp
endpoint_config_response = client.create_endpoint_config(
    EndpointConfigName = endpoint_config_name,
    ProductionVariants=[{
        'InstanceType':'ml.t2.medium',
        'InitialInstanceCount':1,
        'ModelName':model_name,
        'VariantName':'AllTraffic'}])

print('Endpoint configuration name: {}'.format(endpoint_config_name))
print('Endpoint configuration arn:  {}'.format(endpoint_config_response['EndpointConfigArn']))

# %% [markdown]
# ### Create Endpoint
#
# The next cell creates an endpoint that can be validated and incorporated into production applications. This takes about 10 minutes to complete.

# %%
timestamp = time.strftime('-%Y-%m-%d-%H-%M-%S', time.gmtime())
endpoint_name = training_job_name + '-ep' + timestamp
print('Endpoint name: {}'.format(endpoint_name))

endpoint_params = {
    'EndpointName': endpoint_name,
    'EndpointConfigName': endpoint_config_name,
}
endpoint_response = client.create_endpoint(**endpoint_params)
print('EndpointArn = {}'.format(endpoint_response['EndpointArn']))

# %%
endpoint_name="test-tuning-job-008-9ff8af52-ep-2019-07-19-12-25-46"
# get the status of the endpoint
response = client.describe_endpoint(EndpointName=endpoint_name)
status = response['EndpointStatus']
print('EndpointStatus = {}'.format(status))

# %% [markdown]
# ### Perform inference

# %% [markdown]
# We will invoke the deployed endpoint to detect bees in the 10 test images that were inside the `test` folder in `dataset.zip`

# %%
import glob
test_images = glob.glob('test/*')
print(*test_images, sep="\n")

# %% [markdown]
# Next, define a function that converts the prediction array returned by our endpoint to the bounding box structure expected by our image display function.

# %%
def prediction_to_bbox_data(image_path, prediction):
    class_id, confidence, xmin, ymin, xmax, ymax = prediction
    width, height = Image.open(image_path).size
    bbox_data = {'class_id': class_id,
               'height': (ymax-ymin)*height,
               'width': (xmax-xmin)*width,
               'left': xmin*width,
               'top': ymin*height}
    return bbox_data

# %% [markdown]
# Finally, for each of the test images, the following cell transforms the image into the appropriate format for realtime prediction, repeatedly calls the endpoint, receives back the prediction, and displays the result.

# %%
import matplotlib.pyplot as plt

runtime_client = boto3.client('sagemaker-runtime')

# Call SageMaker endpoint to obtain predictions
def get_predictions_for_img(runtime_client, endpoint_name, img_path):
    with open(img_path, 'rb') as f:
        payload = f.read()
        payload = bytearray(payload)

    response = runtime_client.invoke_endpoint(EndpointName=endpoint_name, 
                                       ContentType='application/x-image', 
                                       Body=payload)

    result = response['Body'].read()
    result = json.loads(result)
    return result


# wait until the status has changed
client.get_waiter('endpoint_in_service').wait(EndpointName=endpoint_name)
endpoint_response = client.describe_endpoint(EndpointName=endpoint_name)
status = endpoint_response['EndpointStatus']
if status != 'InService':
    raise Exception('Endpoint creation failed.')

for test_image in test_images:
    result = get_predictions_for_img(runtime_client, endpoint_name, test_image)
    confidence_threshold = .2
    best_n = 3
    # display the best n predictions with confidence > confidence_threshold
    predictions = [prediction for prediction in result['prediction'] if prediction[1] > confidence_threshold]
    predictions.sort(reverse=True, key = lambda x: x[1])
    bboxes = [prediction_to_bbox_data(test_image, prediction) for prediction in predictions[:best_n]]
    show_annotated_image(test_image, bboxes)

# %% [markdown]
# <a name='model_tuning'></a>
# ## Model Tuning
#
# When you configured the training job you needed to add many hyperparameters that affect the performance of the algorithm and the quality of the resulting model. But how do you pick the right hyperparameters?
#
# If you have experience with the specific algorithm and understand the innerworkings of it, you may already have a good sense of appropriate values. But even then, it's impossible to know the exact best value of each hyperparameter. Often you can zero in on the best values by trying many different combination of values, effectively searching in the hyperparameter space. SageMaker makes this extremely easy with the Model Tuning feature, also known as Hyperparameter Optimization (or HPO). With Model Tuning you simply decide which of the hyperparameters you are not sure about and specify the range of values for each that SageMaker needs to explore. Let's see again how this can be accomplished via the console.

# %% [markdown]
# <a name='cleanup'></a>
# ## Cleanup
#
# At the end of the lab we would like to delete the real-time endpoint, as keeping a real-time endpoint around while being idle is costly and wasteful.

# %%
client.delete_endpoint(EndpointName=endpoint_name)
